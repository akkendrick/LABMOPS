# %%
import numpy as np
import os
from PIL import Image

# %%
# slices = []
#
# dir = 'E:\Research\LABMOPS\multiscale_sandyMicrostructure\origin\384\images'
# for filename in os.listdir(dir):
#     if filename.endswith(".tif"):
#         fullName = os.path.join(dir,filename)
#         im = np.array(Image.open(fullName))
#         im[im == 255] = 1
#         slices.append(im)
#         print(type(im))
#
#
# stacked = np.dstack(slices)
#
# final_image = stacked[0:512,0:512,0:512]
# final_image.shape
#
# Out:
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# <class 'numpy.ndarray'>
# ...

# %%
final_image = np.fromfile('E:\Research\LABMOPS\RandomSpherePackingMicrostructure.raw')

# %%
np.save('subBeadPackPy.npy', final_image)
