# %%
import scipy as sp
import numpy as np
import porespy as ps
import matplotlib.pyplot as plt
import scipy.io as sio
import seaborn as sns
import skimage as ski
import tqdm
import find_skeleton
import scipy.stats


imageSize = 250

primaryImage = np.load('subBeadPackPy250_justSpheres.npy')
secondaryImage = np.load('finalSimFile3D250.npy')
primaryImage[primaryImage == 255] = 1

primaryImage = np.transpose(primaryImage)
secondaryImage = np.transpose(secondaryImage)

velSecondaryMat = sio.loadmat('velNormSecondary.mat')
velDataNormSecondary = velSecondaryMat['velNorm']

velPrimaryMat = sio.loadmat('velNormPrimary.mat')
velDataNormPrimary = velPrimaryMat['velNorm']

resolution = 16.81E-6 # adding resolution in meters

# %% [markdown]
# # Plot pore space and velocity

# %% [markdown]
# Plot the sample with secondary porosity

# %%
slice = 35

fig, (p1, p2) = plt.subplots(1, 2)

fig.suptitle('Secondary pore space and velocity map')
p1.imshow(velDataNormSecondary[:,:,slice])
p2.imshow(secondaryImage[:,:,slice])

fig.savefig('secondaryPoreImage.png')

# %%
# testIM = primaryImage.astype(bool)
# testIM = testIM[:,:,slice]
# skelIM = ski.morphology.skeletonize(testIM)
#
# plt.imshow(skelIM)

# %% [markdown]
# # Extract pore network information

# %%
snowFiltSecondary = ps.filters.snow_partitioning(im=secondaryImage,r_max=4,sigma=0.4, return_all=True)
poreInfoSecondary = ps.networks.regions_to_network(snowFiltSecondary.regions, dt=snowFiltSecondary.dt)

nRegions = np.unique(snowFiltSecondary.regions).size
secondaryPoreDiamVec = np.zeros(nRegions,)

for a in range(0, poreInfoSecondary['pore.diameter'].size):
    secondaryPoreDiamVec[a] = poreInfoSecondary['pore.diameter'][a]

secondaryRegions = snowFiltSecondary.regions
# Out:
# ------------------------------------------------------------
# Beginning SNOW Algorithm
# Converting supplied image (im) to boolean
# Peforming Distance Transform
# Applying Gaussian blur with sigma = 0.4
# Initial number of peaks:  1436
# Peaks after trimming saddle points:  938
# Peaks after trimming nearby peaks:  922
# ------------------------------------------------------------
# Extracting pore and throat information from image
# 100%|██████████| 922/922 [00:10<00:00, 90.03it/s]

# %%
ps.io.to_vtk(secondaryRegions,'snowRegionsSecondary')

# %% [markdown]
# # Plot velocity histogram from simulation

# %%
allSecondaryVelocities = np.ndarray.flatten(velDataNormSecondary)

filtIndex = allSecondaryVelocities > 0
trueZeroIndex = allSecondaryVelocities == 0

filtSecondaryVelocities = allSecondaryVelocities[filtIndex]
filtZeroSecondaryVelocities = allSecondaryVelocities[trueZeroIndex]

fig, axes = plt.subplots(1, 1, figsize=(18, 10))
sns.distplot(filtSecondaryVelocities, ax=axes, hist=True, kde=True,
             bins=int(80), color = 'darkblue',
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
axes.set_title('Primary porosity', fontsize=20)
axes.set_xlabel('All pore velocities', fontsize=18)
# Out:
# Text(0.5, 0, 'All pore velocities')

# %% [markdown]
# # Skeleton implementation

# %%
secondaryRegionData = ps.metrics.regionprops_3D(snowFiltSecondary.regions) #Gives properties for each region
# Out:
# 100%|██████████| 922/922 [01:06<00:00, 13.90it/s]
# ------------------------------------------------------------
# Calculating regionprops

# %% [markdown]
# Find skeleton for secondary image and collect info

# %%
len(np.unique(secondaryRegions))
# Out:
# 923

# %%
cubeSize = len(secondaryImage)
secondarySkelImage = np.zeros(secondaryImage.shape)
edgeImage = np.zeros(secondaryImage.shape)
visit = np.zeros(len(np.unique(secondaryRegions)))
secondaryPoreDiamImage = np.zeros(secondaryImage.shape)
regionStepImage = np.zeros(secondaryImage.shape)
skeletonDone = np.zeros(len(np.unique(secondaryRegions)))

poreDiamForMedian = []
for a in tqdm.tqdm(range(0, cubeSize), 'Main loop'):
    for b in range(cubeSize):
        for c in range(cubeSize):
            regionLabel = snowFiltSecondary.regions[a,b,c]
            if regionLabel != 0: # Don't want grains to be counted

                if visit[regionLabel] == 0:
                    visit[regionLabel] = 1
                    #index = snowFiltPrimary.regions[a,b,c]

                    # regionBorder = primaryRegionData[regionLabel].slice
                    # We don't want to use regionBorder or the slice feature! This gives a box outline
                    # not the actual pore!!!
                    # primarySkelImage[primaryRegions == regionLabel] = primaryRegionData[regionLabel].skeleton
                    #edgeImage[snowFiltPrimary.regions[a,b,c] == regionLabel] = regionData[regionLabel].border

                    # secondaryRegionImage[secondaryRegions == regionLabel] =  regionLabel

                    if skeletonDone[regionLabel] == 0:

                        regionStepImage[secondaryRegions == regionLabel] = 1
                        regionSkeleton = ski.morphology.skeletonize(regionStepImage)
                        # Save skeleton for this region
                        secondarySkelImage[secondaryRegions == regionLabel] = regionSkeleton[secondaryRegions == regionLabel]
                        print('skeleton done for ', regionLabel)

                        # Reset for next iteration
                        regionStepImage[secondaryImage == regionLabel] = 0
                        skeletonDone[regionLabel] = 1

                    # Adjust indices for pore information, regionlabel = 0 is pore 1 in poreInfo
                    poreDiam = poreInfoSecondary['pore.diameter'][regionLabel-1]
                    poreDiamForMedian = np.append(poreDiamForMedian, poreInfoSecondary['pore.diameter'][regionLabel-1])
                    secondaryPoreDiamImage[secondaryRegions == regionLabel] = poreDiam
# Out:
# Main loop: 100%|██████████| 250/250 [1:07:56<00:00, 16.31s/it]
# skeleton done for  637
# skeleton done for  907
# skeleton done for  311
# skeleton done for  838
# skeleton done for  549
# skeleton done for  561
# skeleton done for  688
# skeleton done for  456
# skeleton done for  638
# skeleton done for  115
# skeleton done for  190
# skeleton done for  554
# skeleton done for  201
# skeleton done for  489
# skeleton done for  209
# skeleton done for  465
# skeleton done for  418
# skeleton done for  855
# skeleton done for  375
# skeleton done for  55
# skeleton done for  29
# skeleton done for  837
# skeleton done for  9
# skeleton done for  350
# skeleton done for  85
# skeleton done for  30
# skeleton done for  532
# skeleton done for  286
# skeleton done for  238
# skeleton done for  149
# skeleton done for  102
# skeleton done for  310
# skeleton done for  377
# skeleton done for  86
# skeleton done for  729
# skeleton done for  784
# skeleton done for  833
# skeleton done for  711
# skeleton done for  798
# skeleton done for  170
# skeleton done for  458
# skeleton done for  809
# skeleton done for  45
# skeleton done for  173
# skeleton done for  351
# skeleton done for  429
# skeleton done for  165
# skeleton done for  118
# skeleton done for  202
# skeleton done for  738
# skeleton done for  154
# skeleton done for  876
# skeleton done for  676
# skeleton done for  128
# skeleton done for  636
# skeleton done for  147
# skeleton done for  679
# skeleton done for  132
# skeleton done for  27
# skeleton done for  650
# skeleton done for  481
# skeleton done for  179
# skeleton done for  675
# skeleton done for  336
# skeleton done for  529
# skeleton done for  322
# skeleton done for  370
# skeleton done for  696
# skeleton done for  316
# skeleton done for  547
# skeleton done for  501
# skeleton done for  825
# skeleton done for  582
# skeleton done for  751
# skeleton done for  195
# skeleton done for  139
# skeleton done for  739
# skeleton done for  348
# skeleton done for  564
# skeleton done for  670
# skeleton done for  420
# skeleton done for  33
# skeleton done for  916
# skeleton done for  545
# skeleton done for  334
# skeleton done for  250
# skeleton done for  391
# skeleton done for  32
# skeleton done for  794
# skeleton done for  617
# skeleton done for  352
# skeleton done for  416
# skeleton done for  605
# skeleton done for  505
# skeleton done for  6
# skeleton done for  367
# skeleton done for  572
# skeleton done for  58
# skeleton done for  369
# skeleton done for  257
# skeleton done for  417
# skeleton done for  789
# skeleton done for  568
# skeleton done for  446
# skeleton done for  308
# skeleton done for  108
# skeleton done for  491
# skeleton done for  812
# skeleton done for  870
# skeleton done for  4
# skeleton done for  647
# skeleton done for  850
# skeleton done for  290
# skeleton done for  14
# skeleton done for  592
# skeleton done for  393
# skeleton done for  197
# skeleton done for  566
# skeleton done for  50
# skeleton done for  714
# skeleton done for  37
# skeleton done for  403
# skeleton done for  425
# skeleton done for  175
# skeleton done for  732
# skeleton done for  130
# skeleton done for  758
# skeleton done for  59
# skeleton done for  901
# skeleton done for  333
# skeleton done for  150
# skeleton done for  839
# skeleton done for  819
# skeleton done for  634
# skeleton done for  689
# skeleton done for  920
# skeleton done for  655
# skeleton done for  854
# skeleton done for  807
# skeleton done for  625
# skeleton done for  454
# skeleton done for  24
# skeleton done for  594
# skeleton done for  735
# skeleton done for  366
# skeleton done for  610
# skeleton done for  824
# skeleton done for  897
# skeleton done for  226
# skeleton done for  440
# skeleton done for  802
# skeleton done for  412
# skeleton done for  69
# skeleton done for  695
# skeleton done for  661
# skeleton done for  53
# skeleton done for  620
# skeleton done for  183
# skeleton done for  450
# skeleton done for  868
# skeleton done for  557
# skeleton done for  764
# skeleton done for  299
# skeleton done for  507
# skeleton done for  525
# skeleton done for  18

# %%
# Skeleton per pore region
cubeSize = len(secondaryImage)
skeletonImagePerPore = np.zeros(secondaryImage.shape)
visit = np.zeros(len(np.unique(secondaryRegions)))
secondaryPoreDiamImage = np.zeros(secondaryImage.shape)
allSecondaryRegions = np.unique(secondaryRegions)
tempImage = np.zeros(secondaryRegions.shape)

for a in tqdm.tqdm(range(0,len(allSecondaryRegions)), 'Main loop'):
            regionLabel = a
            if regionLabel != 0: # Don't want grains to be counted
                if visit[regionLabel] == 0:
                    visit[regionLabel] = 1

                    tempImage[secondaryRegions == regionLabel] = 1
                    tempImage[secondaryRegions != regionLabel] = 0
                    skeletonImagePerPore = ski.morphology.skeletonize(tempImage)
                    secondarySkelImage[secondaryRegions == regionLabel] = skeletonImagePerPore[secondaryRegions == regionLabel]

                    # Adjust indices for pore information, regionlabel = 0 is pore 1 in poreInfo
                    poreDiam = poreInfoSecondary['pore.diameter'][regionLabel-1]
                    poreDiamForMedian = np.append(poreDiamForMedian, poreInfoSecondary['pore.diameter'][regionLabel-1])
                    secondaryPoreDiamImage[secondaryRegions == regionLabel] = poreDiam
# Out:
# Main loop:  61%|██████    | 560/923 [09:12<05:58,  1.01it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-ffe1a29d5b96> in <module>
#      15                     tempImage[secondaryRegions == regionLabel] = 1
#      16                     tempImage[secondaryRegions != regionLabel] = 0
# ---> 17                     skeletonImagePerPore = ski.morphology.skeletonize(tempImage)
#      18                     secondarySkelImage[secondaryRegions == regionLabel] = skeletonImage[secondaryRegions == regionLabel]
#      19
#
# E:\Conda\lib\site-packages\skimage\morphology\_skeletonize.py in skeletonize(image, method)
#      84                          'images.')
#      85     elif image.ndim == 3 or (image.ndim == 2 and method == 'lee'):
# ---> 86         skeleton = skeletonize_3d(image)
#      87     else:
#      88         raise ValueError('skeletonize requires a 2D or 3D image as input, '
#
# E:\Conda\lib\site-packages\skimage\morphology\_skeletonize.py in skeletonize_3d(image, img)
#     649
#     650     # do the computation
# --> 651     image_o = np.asarray(_compute_thin_image(image_o))
#     652
#     653     # crop it back and restore the original intensity range
#
# skimage\morphology\_skeletonize_3d_cy.pyx in skimage.morphology._skeletonize_3d_cy._compute_thin_image()
#
# E:\Conda\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      14 ]
#      15
# ---> 16 @set_module('numpy')
#      17 def asarray(a, dtype=None, order=None):
#      18     """Convert the input to an array.
#
# KeyboardInterrupt:

# %%
# Skeleton for all pores
cubeSize = len(secondaryImage)
visit = np.zeros(len(np.unique(secondaryRegions)))
secondaryPoreDiamImage = np.zeros(secondaryImage.shape)
allSecondaryRegions = np.unique(secondaryRegions)
tempImage = np.zeros(secondaryRegions.shape)

secondarySkelImage = ski.morphology.skeletonize(secondaryImage)

for a in tqdm.tqdm(range(0,len(allSecondaryRegions)), 'Main loop'):
            regionLabel = a
            if regionLabel != 0: # Don't want grains to be counted
                if visit[regionLabel] == 0:
                    visit[regionLabel] = 1

                    # Adjust indices for pore information, regionlabel = 0 is pore 1 in poreInfo
                    poreDiam = poreInfoSecondary['pore.diameter'][regionLabel-1]
                    poreDiamForMedian = np.append(poreDiamForMedian, poreInfoSecondary['pore.diameter'][regionLabel-1])
                    secondaryPoreDiamImage[secondaryRegions == regionLabel] = poreDiam
# Out:
# Main loop: 100%|██████████| 923/923 [00:15<00:00, 58.45it/s]

# %%
#secondarySkelImage[secondaryImage == 0] = 0
ps.io.to_vtk(secondarySkelImage,'secondarySkeletonWholeImage')

secondaryImageOut = np.copy(secondaryImage)
secondaryImageOut = secondaryImageOut.astype(int)
secondaryImageOut[secondaryImage == 1] = 255
ps.io.to_vtk(secondaryImageOut,'secondaryImage')
secondaryImageOut[primaryImage == 255] = 1

# %%
testRegion = 167
oneRegionImage = np.zeros(secondaryImage.shape)
testRegionBorder = secondaryRegionData[testRegion].slice
oneRegionImage[secondaryRegions == testRegion] = 255

ps.io.to_vtk(oneRegionImage,'oneRegionImage')

# %% [markdown]
# # Skeletonize one pore region using python image library algorithm

# %%
testRegionNum = 44
oneRegionImage = np.zeros(secondaryImage.shape)
oneSkeletonImage = np.zeros(secondaryImage.shape)

testRegion = secondaryRegionData[testRegionNum]

oneRegionImage[secondaryRegions == testRegionNum] = 1
testSkel = ski.morphology.skeletonize(oneRegionImage)
oneSkeletonImage[testSkel > 0] = 200

oneRegionImage[oneRegionImage == 1] = 255
ps.io.to_vtk(oneRegionImage,'oneRegionImage')
ps.io.to_vtk(oneSkeletonImage,'oneSkeletonImage')

# %%
plt.imshow(secondarySkelImage[:,:,40])

# ps.io.to_vtk(primarySkelImage,'PS_skeletonImage')
#primaryImage[primaryImage == 1] = 255 # Make red/blue distinction
#ps.io.to_vtk(primaryImage,'primaryImage')

# %% [markdown]
# # Now plot velocitites on skeleton and extract information

# %%
secondaryVelocitiesSkeleton = []
secondaryPoreDiamSkeleton = []
secondaryPoreRegionSkeleton = []

for a in tqdm.tqdm(range(0,cubeSize), 'Main loop'):
    for b in range(0,cubeSize):
        for c in range(0, cubeSize):
            # If the primary skeleton image is not zero, then save the velocity data
            # The primary skeleton image will be zero for all indices except the skeleton found above which
            # should be the values in the middle of all of the pores, no pore walls etc...
            # This array should contain the velocity data we want to use to define flow/no flow etc...
            if secondarySkelImage[a,b,c] != 0:
                secondaryVelocitiesSkeleton = np.append(secondaryVelocitiesSkeleton,velDataNormSecondary[a,b,c])
                secondaryPoreDiamSkeleton = np.append(secondaryPoreDiamSkeleton, secondaryPoreDiamImage[a,b,c])
                secondaryPoreRegionSkeleton = np.append(secondaryPoreRegionSkeleton, secondaryRegions[a,b,c])
# Out:
# Main loop: 100%|██████████| 250/250 [00:43<00:00,  5.77it/s]

# %%
# The zeros seen here are truely no flow I think, they aren't pore walls and this is after the flow simulation, so
# even though the initial lattice state is v = 0, these are still zero

fig, axes = plt.subplots(1, 2, figsize=(18, 10))
fig.suptitle('Plot velocity data on the Skeleton', fontsize=20)

sns.distplot(secondaryVelocitiesSkeleton, ax=axes[0], hist=True, kde=True,
             bins=int(80), color = 'darkblue',
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
axes[0].set_title('All velocities', fontsize=18)
axes[0].set_xlabel('Pore Velocity', fontsize=18)
axes[0].set_ylabel('Counts', fontsize=20)

sns.distplot(secondaryVelocitiesSkeleton[secondaryVelocitiesSkeleton != 0], ax=axes[1], hist=True, kde=True,
             bins=int(80), color = 'darkblue',
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})
axes[1].set_title('Non-zero velocities', fontsize=20)
axes[1].set_xlabel('Pore Velocity', fontsize=18)
axes[1].set_ylabel('Counts', fontsize=18)

fig.savefig('poreVelHistograms.png')

# %% [markdown]
# # Plot pore velocities with pore diameters

# %%
plt.scatter(secondaryPoreDiamSkeleton, secondaryVelocitiesSkeleton)
plt.xlabel('Pore Diameter (lattice units)', fontsize=18)
plt.ylabel('Pore Velocity on Skeleton ', fontsize=18)
plt.title('All pore velocities on skeleton', fontsize=20)

fig.savefig('allPoreVelocities.png')

# %% [markdown]
# Try taking median velocity

# %%
IQR_PoreVelocity =  []
meanPoreVelocity =  []
skeletonPoreDiam = []
skeletonPoreRegion = []
poreRegions, indices = np.unique(secondaryPoreRegionSkeleton, return_index='True')

for a in range(0, len(poreRegions)):
    currentRegion = poreRegions[a]
    poreRegionIndex = secondaryPoreRegionSkeleton[indices[a]]

    skeletonPoreVel = secondaryVelocitiesSkeleton[secondaryPoreRegionSkeleton == poreRegionIndex]

    meanPoreVelocity = np.append(meanPoreVelocity, np.mean(skeletonPoreVel) )
    IQR_PoreVelocity = np.append(IQR_PoreVelocity, scipy.stats.iqr(skeletonPoreVel, interpolation = 'midpoint'))
    skeletonPoreDiam = np.append(skeletonPoreDiam, poreDiamForMedian[int(poreRegionIndex)] )
    skeletonPoreRegion = np.append(skeletonPoreRegion, int(poreRegionIndex))

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 10))
axes[0].scatter(skeletonPoreDiam, meanPoreVelocity)
axes[0].set_xlabel('Pore Diameter (lattice units)', fontsize=18)
axes[0].set_ylabel('Mean Pore Velocity on Skeleton', fontsize=18)
axes[0].set_title('Mean pore velocities on skeleton', fontsize=20)

axes[1].scatter(skeletonPoreDiam, IQR_PoreVelocity)
axes[1].set_xlabel('Pore Diameter (lattice units)', fontsize=18)
axes[1].set_ylabel('IQR Pore Velocity on Skeleton', fontsize=18)
axes[1].set_title('IQR pore velocities on skeleton', fontsize=20)

fig.savefig('poreVelAveraging.png')

# %% [markdown]
# Separate pores with low velocity

# %%
# Best choice for this? hardcoded to 0 per discussion on 4/2
noFlowVelCutoff = 0 # 0.5 * 10 ** float(-5)
print(noFlowVelCutoff)
# Out:
# 0

# %%
poreRegions, indices = np.unique(secondaryPoreRegionSkeleton, return_index='True')
noFlowRegions = skeletonPoreRegion[IQR_PoreVelocity == 0]
noFlowImage = np.zeros(secondaryImage.shape)
flowImage = np.copy(secondaryImage)

for a in range(0, len(noFlowRegions)):
    regionInd = noFlowRegions[a]
    print('This is a no flow region:', regionInd)
    noFlowImage[secondaryRegions == regionInd] =  1
    flowImage[secondaryRegions == regionInd] = 0
# Out:
# This is a no flow region: 3.0
# This is a no flow region: 6.0
# This is a no flow region: 8.0
# This is a no flow region: 11.0
# This is a no flow region: 17.0
# This is a no flow region: 27.0
# This is a no flow region: 28.0
# This is a no flow region: 37.0
# This is a no flow region: 41.0
# This is a no flow region: 46.0
# This is a no flow region: 48.0
# This is a no flow region: 52.0
# This is a no flow region: 59.0
# This is a no flow region: 60.0
# This is a no flow region: 64.0
# This is a no flow region: 70.0
# This is a no flow region: 71.0
# This is a no flow region: 74.0
# This is a no flow region: 80.0
# This is a no flow region: 82.0
# This is a no flow region: 88.0
# This is a no flow region: 99.0
# This is a no flow region: 101.0
# This is a no flow region: 106.0
# This is a no flow region: 107.0
# This is a no flow region: 108.0
# This is a no flow region: 109.0
# This is a no flow region: 112.0
# This is a no flow region: 114.0
# This is a no flow region: 116.0
# This is a no flow region: 118.0
# This is a no flow region: 120.0
# This is a no flow region: 122.0
# This is a no flow region: 126.0
# This is a no flow region: 129.0
# This is a no flow region: 137.0
# This is a no flow region: 138.0
# This is a no flow region: 142.0
# This is a no flow region: 144.0
# This is a no flow region: 145.0
# This is a no flow region: 147.0
# This is a no flow region: 148.0
# This is a no flow region: 155.0
# This is a no flow region: 156.0
# This is a no flow region: 171.0
# This is a no flow region: 175.0
# This is a no flow region: 179.0
# This is a no flow region: 180.0
# This is a no flow region: 183.0
# This is a no flow region: 187.0
# This is a no flow region: 189.0
# This is a no flow region: 200.0
# This is a no flow region: 204.0
# This is a no flow region: 205.0
# This is a no flow region: 207.0
# This is a no flow region: 208.0
# This is a no flow region: 215.0
# This is a no flow region: 223.0
# This is a no flow region: 224.0
# This is a no flow region: 226.0
# This is a no flow region: 230.0
# This is a no flow region: 231.0
# This is a no flow region: 237.0
# This is a no flow region: 239.0
# This is a no flow region: 242.0
# This is a no flow region: 245.0
# This is a no flow region: 246.0
# This is a no flow region: 247.0
# This is a no flow region: 249.0
# This is a no flow region: 250.0
# This is a no flow region: 252.0
# This is a no flow region: 255.0
# This is a no flow region: 256.0
# This is a no flow region: 258.0
# This is a no flow region: 260.0
# This is a no flow region: 264.0
# This is a no flow region: 267.0
# This is a no flow region: 268.0
# This is a no flow region: 269.0
# This is a no flow region: 271.0
# This is a no flow region: 274.0
# This is a no flow region: 275.0
# This is a no flow region: 278.0
# This is a no flow region: 284.0
# This is a no flow region: 286.0
# This is a no flow region: 290.0
# This is a no flow region: 298.0
# This is a no flow region: 304.0
# This is a no flow region: 305.0
# This is a no flow region: 306.0
# This is a no flow region: 307.0
# This is a no flow region: 309.0
# This is a no flow region: 311.0
# This is a no flow region: 312.0
# This is a no flow region: 313.0
# This is a no flow region: 317.0
# This is a no flow region: 322.0
# This is a no flow region: 331.0
# This is a no flow region: 334.0
# This is a no flow region: 343.0
# This is a no flow region: 344.0
# This is a no flow region: 345.0
# This is a no flow region: 355.0
# This is a no flow region: 358.0
# This is a no flow region: 361.0
# This is a no flow region: 365.0
# This is a no flow region: 368.0
# This is a no flow region: 380.0
# This is a no flow region: 385.0
# This is a no flow region: 393.0
# This is a no flow region: 404.0
# This is a no flow region: 406.0
# This is a no flow region: 408.0
# This is a no flow region: 409.0
# This is a no flow region: 410.0
# This is a no flow region: 411.0
# This is a no flow region: 416.0
# This is a no flow region: 421.0
# This is a no flow region: 424.0
# This is a no flow region: 427.0
# This is a no flow region: 429.0
# This is a no flow region: 431.0
# This is a no flow region: 438.0
# This is a no flow region: 444.0
# This is a no flow region: 447.0
# This is a no flow region: 448.0
# This is a no flow region: 451.0
# This is a no flow region: 452.0
# This is a no flow region: 454.0
# This is a no flow region: 455.0
# This is a no flow region: 456.0
# This is a no flow region: 457.0
# This is a no flow region: 460.0
# This is a no flow region: 466.0
# This is a no flow region: 470.0
# This is a no flow region: 474.0
# This is a no flow region: 475.0
# This is a no flow region: 477.0
# This is a no flow region: 478.0
# This is a no flow region: 481.0
# This is a no flow region: 485.0
# This is a no flow region: 486.0
# This is a no flow region: 487.0
# This is a no flow region: 490.0
# This is a no flow region: 494.0
# This is a no flow region: 505.0
# This is a no flow region: 509.0
# This is a no flow region: 511.0
# This is a no flow region: 513.0
# This is a no flow region: 519.0
# This is a no flow region: 522.0
# This is a no flow region: 523.0
# This is a no flow region: 525.0
# This is a no flow region: 534.0
# This is a no flow region: 536.0
# This is a no flow region: 541.0
# This is a no flow region: 545.0
# This is a no flow region: 555.0
# This is a no flow region: 557.0
# This is a no flow region: 558.0
# This is a no flow region: 563.0
# This is a no flow region: 564.0
# This is a no flow region: 565.0
# This is a no flow region: 569.0
# This is a no flow region: 570.0
# This is a no flow region: 571.0
# This is a no flow region: 573.0
# This is a no flow region: 576.0
# This is a no flow region: 577.0
# This is a no flow region: 578.0
# This is a no flow region: 580.0
# This is a no flow region: 585.0
# This is a no flow region: 589.0
# This is a no flow region: 590.0
# This is a no flow region: 592.0
# This is a no flow region: 593.0
# This is a no flow region: 598.0
# This is a no flow region: 599.0
# This is a no flow region: 603.0
# This is a no flow region: 604.0
# This is a no flow region: 606.0
# This is a no flow region: 607.0
# This is a no flow region: 612.0
# This is a no flow region: 613.0
# This is a no flow region: 614.0
# This is a no flow region: 615.0
# This is a no flow region: 618.0
# This is a no flow region: 619.0
# This is a no flow region: 620.0
# This is a no flow region: 622.0
# This is a no flow region: 631.0
# This is a no flow region: 633.0
# This is a no flow region: 634.0
# This is a no flow region: 636.0
# This is a no flow region: 638.0
# This is a no flow region: 639.0
# This is a no flow region: 642.0
# This is a no flow region: 644.0
# This is a no flow region: 646.0
# This is a no flow region: 657.0
# This is a no flow region: 659.0
# This is a no flow region: 660.0
# This is a no flow region: 662.0
# This is a no flow region: 664.0
# This is a no flow region: 668.0
# This is a no flow region: 669.0
# This is a no flow region: 673.0
# This is a no flow region: 674.0
# This is a no flow region: 676.0
# This is a no flow region: 682.0
# This is a no flow region: 685.0
# This is a no flow region: 687.0
# This is a no flow region: 688.0
# This is a no flow region: 690.0
# This is a no flow region: 694.0
# This is a no flow region: 697.0
# This is a no flow region: 701.0
# This is a no flow region: 702.0
# This is a no flow region: 703.0
# This is a no flow region: 704.0
# This is a no flow region: 714.0
# This is a no flow region: 715.0
# This is a no flow region: 717.0
# This is a no flow region: 718.0
# This is a no flow region: 721.0
# This is a no flow region: 722.0
# This is a no flow region: 727.0
# This is a no flow region: 730.0
# This is a no flow region: 731.0
# This is a no flow region: 738.0
# This is a no flow region: 747.0
# This is a no flow region: 750.0
# This is a no flow region: 755.0
# This is a no flow region: 756.0
# This is a no flow region: 761.0
# This is a no flow region: 763.0
# This is a no flow region: 764.0
# This is a no flow region: 768.0
# This is a no flow region: 770.0
# This is a no flow region: 771.0
# This is a no flow region: 775.0
# This is a no flow region: 779.0
# This is a no flow region: 781.0
# This is a no flow region: 788.0
# This is a no flow region: 791.0
# This is a no flow region: 795.0
# This is a no flow region: 798.0
# This is a no flow region: 799.0
# This is a no flow region: 806.0
# This is a no flow region: 807.0
# This is a no flow region: 812.0
# This is a no flow region: 813.0
# This is a no flow region: 818.0
# This is a no flow region: 820.0
# This is a no flow region: 821.0
# This is a no flow region: 825.0
# This is a no flow region: 829.0
# This is a no flow region: 831.0
# This is a no flow region: 832.0
# This is a no flow region: 835.0
# This is a no flow region: 840.0
# This is a no flow region: 843.0
# This is a no flow region: 847.0
# This is a no flow region: 848.0
# This is a no flow region: 849.0
# This is a no flow region: 850.0
# This is a no flow region: 854.0
# This is a no flow region: 857.0
# This is a no flow region: 863.0
# This is a no flow region: 864.0
# This is a no flow region: 867.0
# This is a no flow region: 868.0
# This is a no flow region: 870.0
# This is a no flow region: 871.0
# This is a no flow region: 872.0
# This is a no flow region: 873.0
# This is a no flow region: 875.0
# This is a no flow region: 879.0
# This is a no flow region: 880.0
# This is a no flow region: 883.0
# This is a no flow region: 887.0
# This is a no flow region: 895.0
# This is a no flow region: 896.0
# This is a no flow region: 897.0
# This is a no flow region: 904.0
# This is a no flow region: 905.0
# This is a no flow region: 911.0
# This is a no flow region: 915.0
# This is a no flow region: 916.0
# This is a no flow region: 920.0

# %%
# Rescale no Flow data
velImage = velDataNormSecondary
velImage = velImage / np.max(velImage)
velImage = velImage * 200
ps.io.to_vtk(velImage,'secondaryVelocityImage')

noFlowOut = noFlowImage
noFlowOut[noFlowImage == 1] = 255
ps.io.to_vtk(noFlowImage,'noFlowSecondaryRegionImage')

# %% [markdown]
# # Compute estimate of mobile porosity

# %% [markdown]
# Total Porosity

# %%
porosityCalc = ps.metrics.porosity(secondaryImage)
print('Total porosity:')
print(porosityCalc)
# Out:
# Total porosity:
# 0.545888832

# %% [markdown]
# Estimate of mobile porosity

# %%
# Get grains
flippedImage = np.copy(secondaryImage)
flippedImage[secondaryImage == 1] = 0
flippedImage[secondaryImage == 0] = 1
porosityCalc = ps.metrics.porosity(secondaryImage)

sumPorosity = np.sum(secondaryImage)/(np.sum(flippedImage)+np.sum(secondaryImage))
print(sumPorosity)

mobileOnes = np.sum(flowImage)
total = np.sum(flippedImage) + np.sum(flowImage) + np.sum(noFlowImage)
mobilePorosity = mobileOnes/total
print('Mobile porosity estimate:')
print(mobilePorosity)
print('Mobile fraction of porosity')
mobileFrac = (mobilePorosity/porosityCalc)
print(mobileFrac)
# Out:
# 0.545888832
# Mobile porosity estimate:
# 0.487801728
# Mobile fraction of porosity
# 0.8935916974392324

# %%
dispIM = np.copy(secondaryImage)
dispIM[secondaryImage == 1] = 255
#dispIM[secondaryImage == 1] = 0
totalPorosityImage = ps.visualization.show_3D(dispIM)
plt.imshow(totalPorosityImage)

plt.savefig('allPoreImage.png')

# %%
dispIM = np.copy(flowImage)
dispIM[flowImage == 0] = 255
dispIM[flowImage == 1] = 0
dispFlowImage = ps.visualization.show_3D(dispIM)
plt.imshow(dispFlowImage)

plt.savefig('flowImage.png')
